# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('./train.csv').values
test = pd.read_csv('./test.csv').values

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset

# %%
class Digit(nn.Module):
    def __init__(self):
        super(Digit, self).__init__()
        self.conv11 = nn.Conv2d(1, 32, 3, padding=1)
        self.conv12 = nn.Conv2d(32, 32, 3, padding=1)
        self.bn11 = nn.BatchNorm2d(32)
        self.bn12 = nn.BatchNorm2d(32)
        self.pool1 = nn.AvgPool2d(2, stride=2)
        
        self.conv21 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv22 = nn.Conv2d(64, 64, 3, padding=1)
        self.bn21 = nn.BatchNorm2d(64)
        self.bn22 = nn.BatchNorm2d(64)
        self.pool2 = nn.AvgPool2d(2, stride=2)
        
        self.conv31 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv32 = nn.Conv2d(128, 128, 3, padding=1)
        self.bn31 = nn.BatchNorm2d(128)
        self.bn32 = nn.BatchNorm2d(128)
        self.pool3 = nn.AvgPool2d(2, stride=2)
        
        self.pool4 = nn.AvgPool2d(3)
        self.fc1 = nn.Linear(128, 10)
        
        
    def forward(self, images):
        output = F.relu(self.bn11(self.conv11(images)))
        output = F.relu(self.bn12(self.conv12(output)))
        output = self.pool1(output)
        output = F.relu(self.bn21(self.conv21(output)))
        output = F.relu(self.bn22(self.conv22(output)))
        output = self.pool2(output)
        output = F.relu(self.bn31(self.conv31(output)))
        output = F.relu(self.bn32(self.conv32(output)))
        output = self.pool3(output)
        output = self.pool4(output).view(-1, 128)
        output = self.fc1(output)
        
        
        return F.log_softmax(output)

# %%
class DigitDataset(Dataset):
    def __init__(self, index):
        self.train = train[index]
    
    def __getitem__(self, index):
        features = self.train[index, 1:].reshape(1,28,28).astype('float32')
        target = self.train[index, 0]
        return features, target
    
    def __len__(self):
        return self.train.shape[0]

# %%
from sklearn.cross_validation import KFold
from sklearn.metrics import accuracy_score

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
SEED = 0
NFOLDS = 5
kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)

# %%
torch.cuda.set_device(2)

# %%
def get_oof_nn():
    oof_train = np.zeros((ntrain,))
    oof_test = torch.zeros((ntest))
    oof_test_skf = torch.zeros((NFOLDS, ntest, 10))

    outcomes = []
    
    print('clf: nn_titan')
    
    for i, (train_index, test_index) in enumerate(kf):
        train_DDS = DigitDataset(train_index)
        train_iter = DataLoader(train_DDS, batch_size=200, shuffle=True, num_workers=12)
        test_DDS = DigitDataset(test_index)
        test_iter = DataLoader(test_DDS, batch_size=200, shuffle=True, num_workers=12)
        
        digit = Digit()
        digit = digit.cuda()

        loss_fn = nn.NLLLoss()
        loss_fn = loss_fn.cuda()

        optimizer = torch.optim.Adam(digit.parameters(), lr=1e-3)
        
        best_val, best_step = 0.0, 0
        

        for epoch in range(1000):
        
            for k, (features, targets) in enumerate(train_iter):
                digit.train()
                pred_train = digit(Variable(features.cuda()))
                y_train = Variable(targets.cuda())
                loss = loss_fn(pred_train, y_train)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        

            val_accu = []

            for k, (features, targets) in enumerate(test_iter):
                digit.eval()
                pred_val = digit(Variable(features.cuda())).data.max(1)[1].view(-1)
                pred_val = pred_val.cpu().numpy()
                targets = targets.numpy()
                
                accuracy = accuracy_score(targets, pred_val)
                
                val_accu.append(accuracy)
                

            val_accu = np.asanyarray(val_accu).mean()
            print('epoch: ', epoch , '\t best_accu: ', best_val)
            
            if (val_accu>best_val):
                best_val = val_accu
                best_step = epoch
                torch.save(digit.state_dict(), 'digit_model2.pkl')

            if (epoch-best_step >= 10):
                print('best_val_%d: %.5f' %(i, best_val))
                outcomes.append(best_val)
                break
        
      
        test_iter = DataLoader(test, batch_size=200)
        digit.load_state_dict(torch.load('digit_model2.pkl'))
        digit.eval()
        pred_val_arr = []
        for k, features in enumerate(test_iter):
            features = features.float().view(-1, 1, 28, 28)
            pred_val = digit(Variable(features.cuda()))
            pred_val = pred_val.data.cpu()
            pred_val_arr.append(pred_val)
        
        oof_test_skf[i, :] = torch.cat(pred_val_arr)

    print(oof_test_skf.mean(dim=0).max(2)[1].size())
    oof_test[:] = oof_test_skf.mean(dim=0).max(2)[1].view(-1)
    
    oof_test = oof_test.numpy()
    
    print('oof_test: ', oof_test.shape)
       
    mean_outcome = np.mean(outcomes)
    print("Mean Accuracy: {0}".format(mean_outcome)) 
    
    return oof_test

# %%
oof_test = get_oof_nn()
# Out:
# clf: nn_titan
# epoch:  0 	 best_accu:  0.0
# epoch:  1 	 best_accu:  0.97880952381
# epoch:  2 	 best_accu:  0.98119047619
# epoch:  3 	 best_accu:  0.98119047619
# epoch:  4 	 best_accu:  0.99119047619
# epoch:  5 	 best_accu:  0.99119047619
# epoch:  6 	 best_accu:  0.99119047619
# epoch:  7 	 best_accu:  0.99119047619
# epoch:  8 	 best_accu:  0.99119047619
# epoch:  9 	 best_accu:  0.99369047619
# epoch:  10 	 best_accu:  0.99369047619
# epoch:  11 	 best_accu:  0.99369047619
# epoch:  12 	 best_accu:  0.99369047619
# epoch:  13 	 best_accu:  0.99369047619
# epoch:  14 	 best_accu:  0.99369047619
# epoch:  15 	 best_accu:  0.99369047619
# epoch:  16 	 best_accu:  0.99369047619
# epoch:  17 	 best_accu:  0.99369047619
# epoch:  18 	 best_accu:  0.99369047619
# best_val_0: 0.99369
# epoch:  0 	 best_accu:  0.0
# epoch:  1 	 best_accu:  0.971428571429
# epoch:  2 	 best_accu:  0.986547619048
# epoch:  3 	 best_accu:  0.986547619048
# epoch:  4 	 best_accu:  0.986547619048
# epoch:  5 	 best_accu:  0.986547619048
# epoch:  6 	 best_accu:  0.99130952381
# epoch:  7 	 best_accu:  0.99130952381
# epoch:  8 	 best_accu:  0.99130952381
# epoch:  9 	 best_accu:  0.99130952381
# epoch:  10 	 best_accu:  0.99130952381
# epoch:  11 	 best_accu:  0.99130952381
# epoch:  12 	 best_accu:  0.99130952381
# epoch:  13 	 best_accu:  0.992023809524
# epoch:  14 	 best_accu:  0.992023809524
# epoch:  15 	 best_accu:  0.992023809524
# epoch:  16 	 best_accu:  0.992261904762
# epoch:  17 	 best_accu:  0.992261904762
# epoch:  18 	 best_accu:  0.992261904762
# epoch:  19 	 best_accu:  0.993571428571
# epoch:  20 	 best_accu:  0.993928571429
# epoch:  21 	 best_accu:  0.993928571429
# epoch:  22 	 best_accu:  0.993928571429
# epoch:  23 	 best_accu:  0.993928571429
# epoch:  24 	 best_accu:  0.993928571429
# epoch:  25 	 best_accu:  0.993928571429
# epoch:  26 	 best_accu:  0.993928571429
# epoch:  27 	 best_accu:  0.993928571429
# epoch:  28 	 best_accu:  0.994047619048
# epoch:  29 	 best_accu:  0.994047619048
# epoch:  30 	 best_accu:  0.994047619048
# epoch:  31 	 best_accu:  0.994047619048
# epoch:  32 	 best_accu:  0.994642857143
# epoch:  33 	 best_accu:  0.994642857143
# epoch:  34 	 best_accu:  0.994642857143
# epoch:  35 	 best_accu:  0.994642857143
# epoch:  36 	 best_accu:  0.994642857143
# epoch:  37 	 best_accu:  0.994642857143
# epoch:  38 	 best_accu:  0.994642857143
# epoch:  39 	 best_accu:  0.994642857143
# epoch:  40 	 best_accu:  0.994642857143
# epoch:  41 	 best_accu:  0.994642857143
# best_val_1: 0.99464
# epoch:  0 	 best_accu:  0.0
# epoch:  1 	 best_accu:  0.984761904762
# epoch:  2 	 best_accu:  0.988452380952
# epoch:  3 	 best_accu:  0.990357142857
# epoch:  4 	 best_accu:  0.9925
# epoch:  5 	 best_accu:  0.9925
# epoch:  6 	 best_accu:  0.9925
# epoch:  7 	 best_accu:  0.9925
# epoch:  8 	 best_accu:  0.9925
# epoch:  9 	 best_accu:  0.9925
# epoch:  10 	 best_accu:  0.9925
# epoch:  11 	 best_accu:  0.993452380952
# epoch:  12 	 best_accu:  0.993452380952
# epoch:  13 	 best_accu:  0.993571428571
# epoch:  14 	 best_accu:  0.993571428571
# epoch:  15 	 best_accu:  0.993571428571
# epoch:  16 	 best_accu:  0.993571428571
# epoch:  17 	 best_accu:  0.993571428571
# epoch:  18 	 best_accu:  0.993571428571
# epoch:  19 	 best_accu:  0.993571428571
# epoch:  20 	 best_accu:  0.994285714286
# epoch:  21 	 best_accu:  0.994285714286
# epoch:  22 	 best_accu:  0.994285714286
# epoch:  23 	 best_accu:  0.994285714286
# epoch:  24 	 best_accu:  0.994285714286
# epoch:  25 	 best_accu:  0.994285714286
# epoch:  26 	 best_accu:  0.994404761905
# epoch:  27 	 best_accu:  0.994404761905
# epoch:  28 	 best_accu:  0.994404761905
# epoch:  29 	 best_accu:  0.994404761905
# epoch:  30 	 best_accu:  0.994404761905
# epoch:  31 	 best_accu:  0.994404761905
# epoch:  32 	 best_accu:  0.994404761905
# epoch:  33 	 best_accu:  0.994404761905
# epoch:  34 	 best_accu:  0.994404761905
# epoch:  35 	 best_accu:  0.994404761905
# best_val_2: 0.99440
# epoch:  0 	 best_accu:  0.0
# epoch:  1 	 best_accu:  0.970952380952
# epoch:  2 	 best_accu:  0.98630952381
# epoch:  3 	 best_accu:  0.98630952381
# epoch:  4 	 best_accu:  0.989523809524
# epoch:  5 	 best_accu:  0.992023809524
# epoch:  6 	 best_accu:  0.992023809524
# epoch:  7 	 best_accu:  0.992023809524
# epoch:  8 	 best_accu:  0.992023809524
# epoch:  9 	 best_accu:  0.992023809524
# epoch:  10 	 best_accu:  0.992023809524
# epoch:  11 	 best_accu:  0.992023809524
# epoch:  12 	 best_accu:  0.992023809524
# epoch:  13 	 best_accu:  0.992976190476
# epoch:  14 	 best_accu:  0.992976190476
# epoch:  15 	 best_accu:  0.992976190476
# epoch:  16 	 best_accu:  0.992976190476
# epoch:  17 	 best_accu:  0.992976190476
# epoch:  18 	 best_accu:  0.993095238095
# epoch:  19 	 best_accu:  0.993928571429
# epoch:  20 	 best_accu:  0.993928571429
# epoch:  21 	 best_accu:  0.993928571429
# epoch:  22 	 best_accu:  0.993928571429
# epoch:  23 	 best_accu:  0.993928571429
# epoch:  24 	 best_accu:  0.993928571429
# epoch:  25 	 best_accu:  0.993928571429
# epoch:  26 	 best_accu:  0.993928571429
# epoch:  27 	 best_accu:  0.993928571429
# epoch:  28 	 best_accu:  0.993928571429
# best_val_3: 0.99393
# epoch:  0 	 best_accu:  0.0
# epoch:  1 	 best_accu:  0.985
# epoch:  2 	 best_accu:  0.985
# epoch:  3 	 best_accu:  0.985
# epoch:  4 	 best_accu:  0.985
# epoch:  5 	 best_accu:  0.985
# epoch:  6 	 best_accu:  0.985
# epoch:  7 	 best_accu:  0.990595238095
# epoch:  8 	 best_accu:  0.990595238095
# epoch:  9 	 best_accu:  0.990833333333
# epoch:  10 	 best_accu:  0.990833333333
# epoch:  11 	 best_accu:  0.990833333333
# epoch:  12 	 best_accu:  0.990833333333
# epoch:  13 	 best_accu:  0.99130952381
# epoch:  14 	 best_accu:  0.99130952381
# epoch:  15 	 best_accu:  0.991428571429
# epoch:  16 	 best_accu:  0.991428571429
# epoch:  17 	 best_accu:  0.991428571429
# epoch:  18 	 best_accu:  0.993214285714
# epoch:  19 	 best_accu:  0.993214285714
# epoch:  20 	 best_accu:  0.993214285714
# epoch:  21 	 best_accu:  0.993214285714
# epoch:  22 	 best_accu:  0.993214285714
# epoch:  23 	 best_accu:  0.993452380952
# epoch:  24 	 best_accu:  0.993452380952
# epoch:  25 	 best_accu:  0.993452380952
# epoch:  26 	 best_accu:  0.993452380952
# epoch:  27 	 best_accu:  0.993452380952
# epoch:  28 	 best_accu:  0.993452380952
# epoch:  29 	 best_accu:  0.993452380952
# epoch:  30 	 best_accu:  0.993452380952
# epoch:  31 	 best_accu:  0.993452380952
# epoch:  32 	 best_accu:  0.993452380952
# epoch:  33 	 best_accu:  0.994642857143
# epoch:  34 	 best_accu:  0.995
# epoch:  35 	 best_accu:  0.995
# epoch:  36 	 best_accu:  0.995
# epoch:  37 	 best_accu:  0.995
# epoch:  38 	 best_accu:  0.995
# epoch:  39 	 best_accu:  0.995
# epoch:  40 	 best_accu:  0.995
# epoch:  41 	 best_accu:  0.995
# epoch:  42 	 best_accu:  0.995
# epoch:  43 	 best_accu:  0.995
# best_val_4: 0.99500
# torch.Size([1, 28000, 1])
# oof_test:  (28000,)
# Mean Accuracy: 0.9943333333333333

# %%
oof_test = oof_test.astype('int')

# %%
submissions=pd.DataFrame({"ImageId": list(range(1,len(oof_test)+1)),
                         "Label": oof_test})
submissions.to_csv("DR.csv", index=False, header=True)
